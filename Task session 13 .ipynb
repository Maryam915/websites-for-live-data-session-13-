# %% [markdown]
#                                          # Live Data ( websites Names) #
#
# A) For internet activity in real time
#
# 1.Internet Live Stats
#
# 2.GIF Hell
#
# 3.Emoji Tracker
#
# 4.The Pirate Cinema
#
# 5.Google Trends Visualizer
#
# 6.Tweeplers
#
# 7.Wikipedia Vision
#
# 8.Trendsmap
#
#
# B) For corona live data
#
# 1.worldometer
#
# 2.WHO Coronavirus
#
# 3.COVID-19.direct
#
#
#
# C) For live economic data
#
# 1.trading economics
#
#
# D)live data website for stock market
#
# 1.Nasdaq
#
# 2.Investing.com
#
#
# E)Live Football Scores and Real-Time Football Results
#
# 1.live score
#
# 2.Live Football Scores
#
# 3.Soccer Live Scores
#
# 4.Football Live Scores
#
#
# f)live data for weather
#
# 1.Wind Map
#
# 2.Wikipedia Vision
#
# 3.Weather Radar Compilation
#
#
# //Websites to Find Statistics
#
# Statista.
#
# Gallup.
#
# Pew Research.
#
# Data.gov.
#
# UN Statistical Division.
#
# Google Public Data Explorer.
#
# Knoema
